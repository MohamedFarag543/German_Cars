# %% [markdown]
# # Introduction:
# The dataset from Kaggle from this link https://www.kaggle.com/datasets/ander289386/cars-germany

# %% [markdown]
# # Questions:
# 1-what is the highest Horsepower?
# 2-what is the lowest Horsepower?
# 3-what is the highest price?
# 4-what is the lowest price?
# 5-what is the most frequent car?
# 6-what is the highest mileage?
# 7-what is the lowest mileage?
# 8-what is the most frequent model?
# 9-what is the min frequent model?
# 10-what is the most frequent type of fuel?
# 11-what is the most frequent type of gear?
# 12-what is the correliation between every column?
# 13-heatmap for realationships between every column
# 14-How many cars that realeased in each year?
# 15-how many cars that realted by gear?
# 16-how many cars for each Company?
# 17-How many cars for each model?
# 18-what is the lowest price for all?
# 19-how many cars that relased in 2022>

# %%
import pandas as pd 
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import datetime

# %%
cars = pd.read_csv("autoscout24-germany-dataset.csv")

# %%
cars
# Out:
#        mileage        make   model               fuel    gear       offerType  \
# 0       235000         BMW     316             Diesel  Manual            Used
# 1        92800  Volkswagen    Golf           Gasoline  Manual            Used
# 2       149300        SEAT    Exeo           Gasoline  Manual            Used
# 3        96200     Renault  Megane           Gasoline  Manual            Used
# 4       156000     Peugeot     308           Gasoline  Manual            Used
# ...        ...         ...     ...                ...     ...             ...
# 46400       99        Fiat     500  Electric/Gasoline  Manual  Pre-registered
# 46401       99        Fiat     500  Electric/Gasoline  Manual  Pre-registered
# 46402       99        Fiat     500  Electric/Gasoline  Manual  Pre-registered
# 46403       99        Fiat     500  Electric/Gasoline  Manual  Pre-registered
# 46404       99        Fiat     500  Electric/Gasoline  Manual  Pre-registered
#
#        price     hp  year
# ...

# %%
cars.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 46405 entries, 0 to 46404
# Data columns (total 9 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   mileage    46405 non-null  int64
#  1   make       46405 non-null  object
#  2   model      46262 non-null  object
#  3   fuel       46405 non-null  object
#  4   gear       46223 non-null  object
#  5   offerType  46405 non-null  object
#  6   price      46405 non-null  int64
#  7   hp         46376 non-null  float64
#  8   year       46405 non-null  int64
# dtypes: float64(1), int64(3), object(5)
# memory usage: 3.2+ MB

# %% [markdown]
# cars.isnull().sum()

# %%
cars.isnull()
# Out:
#        mileage   make  model   fuel   gear  offerType  price     hp   year
# 0        False  False  False  False  False      False  False  False  False
# 1        False  False  False  False  False      False  False  False  False
# 2        False  False  False  False  False      False  False  False  False
# 3        False  False  False  False  False      False  False  False  False
# 4        False  False  False  False  False      False  False  False  False
# ...        ...    ...    ...    ...    ...        ...    ...    ...    ...
# 46400    False  False  False  False  False      False  False  False  False
# 46401    False  False  False  False  False      False  False  False  False
# 46402    False  False  False  False  False      False  False  False  False
# 46403    False  False  False  False  False      False  False  False  False
# 46404    False  False  False  False  False      False  False  False  False
#
# [46405 rows x 9 columns]

# %%
from sklearn.impute import SimpleImputer

# %%
imputer = SimpleImputer(strategy= 'most_frequent')
cars['model']=imputer.fit_transform(cars[['model']])
cars['gear']=imputer.fit_transform(cars[['gear']])

# %%
cars.isnull().sum()
# Out:
# mileage       0
# make          0
# model         0
# fuel          0
# gear          0
# offerType     0
# price         0
# hp           29
# year          0
# dtype: int64

# %%
from sklearn.impute import KNNImputer

# %%
imputer = KNNImputer()

# %%
cars['hp']=imputer.fit_transform(cars[['hp']])

# %%
cars.isnull().sum()
# Out:
# mileage      0
# make         0
# model        0
# fuel         0
# gear         0
# offerType    0
# price        0
# hp           0
# year         0
# dtype: int64

# %%
# !pip install datasist

# %%
from  datasist.structdata import detect_outliers

# %%
sns.boxplot(x='mileage',data=cars)
# Out:
# <Axes: xlabel='mileage'>

# %%
idx=detect_outliers(cars,0,['mileage','hp','year','price'])

# %%
idx
# Out:
# [0,
#  12,
#  26,
#  44,
#  50,
#  81,
#  84,
#  93,
#  253,
#  304,
#  407,
#  409,
#  416,
#  436,
#  439,
#  450,
#  614,
#  621,
#  622,
#  627,
#  653,
#  657,
#  690,
#  721,
#  806,
#  821,
#  836,
#  924,
#  1222,
#  1284,
#  1287,
#  1301,
#  1456,
#  1482,
#  1522,
#  1526,
#  1547,
#  1550,
#  1666,
#  1668,
#  1702,
#  1732,
#  1762,
#  1903,
#  2068,
#  2080,
#  2081,
#  2084,
#  2101,
#  2115,
#  2145,
#  2163,
#  2175,
#  2294,
#  2301,
#  2306,
#  2309,
#  2318,
#  2322,
#  2336,
#  2380,
#  2508,
#  2541,
#  2550,
#  2560,
#  2566,
#  2703,
#  2704,
#  2728,
#  2747,
#  2752,
#  2763,
#  2945,
#  2972,
#  2985,
#  3138,
#  3170,
#  3245,
#  3268,
#  3366,
#  3475,
#  3510,
#  3580,
#  3791,
#  3795,
#  3797,
#  3870,
#  3880,
#  4027,
#  4030,
#  4039,
#  4044,
#  4078,
#  4247,
#  4441,
#  4484,
#  4529,
#  4676,
#  4717,
#  4790,
#  4913,
#  4930,
#  4933,
#  4947,
#  4958,
#  4959,
#  4981,
#  4983,
#  5075,
#  5095,
#  5099,
#  5119,
#  5178,
#  5287,
#  5303,
# ...

# %% [markdown]
# # what is the highest Horsepower?

# %%
cars[cars['hp'] == cars['hp'].max()]
# Out:
#        mileage           make     model      fuel       gear offerType  \
# 43126     9234  Mercedes-Benz  G 63 AMG  Gasoline  Automatic      Used
#
#         price     hp  age
# 43126  216619  850.0    4

# %% [markdown]
# # what is the lowest Horsepower?

# %%
cars[cars['hp'] == cars['hp'].min()]
# Out:
#        mileage              make   model               fuel    gear  \
# 9110    167000           Renault  Megane             Diesel  Manual
# 13030      800            Others    Golf             Others  Manual
# 25878     2000            Others    Golf             Others  Manual
# 26088     2000            Others    Golf             Others  Manual
# 28064      100        Volkswagen    Golf             Others  Manual
# 28065      100  Trailer-Anhänger    Golf             Others  Manual
# 36204   302000            Toyota  Prius+  Electric/Gasoline  Manual
# 44072        1  Trailer-Anhänger    Golf             Others  Manual
# 44540     5000             Volvo    Golf             Others  Manual
#
#            offerType  price   hp  age
# 9110            Used   5450  1.0   11
# 13030           Used   2450  1.0    4
# 25878           Used  10999  1.0    8
# 26088           Used  10999  1.0    8
# 28064  Demonstration   2600  1.0    4
# 28065           Used   2800  1.0    4
# ...

# %% [markdown]
# ## what is the highest price?

# %%
cars[cars['price'] == cars['price'].max()]
# Out:
#        mileage     make model      fuel       gear offerType    price     hp  \
# 21675      431  Ferrari   F12  Gasoline  Automatic      Used  1199900  775.0
#
#        age
# 21675    6

# %% [markdown]
# # what is the lowest price?

# %%
#what is the lowest price?
cars[cars['price'] == cars['price'].min()]
# Out:
#        mileage     make model      fuel    gear offerType  price    hp  age
# 23464   204000  Citroen    C1  Gasoline  Manual      Used   1100  68.0   12

# %% [markdown]
# # what is the most frequent car?

# %%
cars['make'].value_counts()
# Out:
# Volkswagen    6931
# Opel          4814
# Ford          4442
# Skoda         2889
# Renault       2830
#               ...
# DAF              1
# Isuzu            1
# Trucks-Lkw       1
# Tazzari          1
# Zhidou           1
# Name: make, Length: 77, dtype: int64

# %%
sns.set(rc={'figure.figsize':[20,20]},font_scale=1.2)

sns.countplot(y='make',data=cars)
# Out:
# <Axes: xlabel='count', ylabel='make'>

# %% [markdown]
# # what is the highest mileage?

# %%
cars[cars['mileage'] == cars['mileage'].max()]
# Out:
#        mileage  make model      fuel    gear      offerType  price    hp  age
# 16869  1111111  Opel  Karl  Gasoline  Manual  Demonstration  10490  73.0    4

# %% [markdown]
# # what is the lowest mileage?

# %%
cars[cars['mileage'] == cars['mileage'].min()]
# Out:
#        mileage     make            model      fuel       gear       offerType  \
# 2276         0  Hyundai             Kona  Electric     Manual            Used
# 2909         0     Land  Rover Discovery    Diesel  Automatic   Demonstration
# 5054         0  Hyundai              i10  Gasoline     Manual             New
# 5673         0  Hyundai              i30  Gasoline  Automatic   Demonstration
# 6110         0  Renault             Clio  Gasoline     Manual  Pre-registered
# ...        ...      ...              ...       ...        ...             ...
# 45900        0     Fiat              500  Gasoline     Manual  Pre-registered
# 45914        0   Abarth             595C  Gasoline     Manual   Demonstration
# 45979        0    Skoda            Kamiq  Gasoline     Manual  Pre-registered
# 45996        0    Dacia           Duster  Gasoline     Manual  Pre-registered
# 46123        0  Renault         Talisman    Diesel     Manual  Pre-registered
#
#        price     hp  age
# ...

# %% [markdown]
# # what is the most frequent model?

# %%
cars['model'].mode()
# Out:
# 0    Golf
# Name: model, dtype: object

# %% [markdown]
# # what is the min frequent model?

# %%
cars['model'].value_counts()
# Out:
# Golf                         1635
# Corsa                        1491
# Fiesta                       1289
# Astra                        1191
# Focus                         985
#                              ...
# S60 Cross Country               1
# John Cooper Works Clubman       1
# 323                             1
# Rodius                          1
# NV250                           1
# Name: model, Length: 841, dtype: int64

# %% [markdown]
# # what is the most frequent type of fuel?

# %%
sns.countplot(x='fuel',data=cars)
# Out:
# <Axes: xlabel='fuel', ylabel='count'>

# %% [markdown]
# # what is the most frequent type of gear?

# %%
sns.countplot(x='gear',data=cars)
# Out:
# <Axes: xlabel='gear', ylabel='count'>

# %% [markdown]
# # realationship between every column

# %%
cars.corr()
# Out:
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_13736\4092122903.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   cars.corr()
#           mileage     price        hp       age
# mileage  1.000000 -0.302788 -0.015041  0.676131
# price   -0.302788  1.000000  0.747527 -0.405633
# hp      -0.015041  0.747527  1.000000 -0.167163
# age      0.676131 -0.405633 -0.167163  1.000000

# %% [markdown]
# # heatmap for realationships between every column

# %%
#
sns.heatmap(cars.corr(),annot=True)
# Out:
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_13736\2373089810.py:2: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(cars.corr(),annot=True)
# <Axes: >

# %% [markdown]
# # How many cars that realeased in each year?

# %%
cars.groupby('age').describe()
# Out:
#     mileage                                                                    \
#       count           mean           std    min       25%       50%       75%
# age
# 2    4181.0    1102.222913   2819.280182    0.0     10.00      25.0    1056.0
# 3    4286.0    9623.436304   8405.181651    0.0   2402.00    8212.0   15000.0
# 4    4233.0   22978.886133  26398.633434    0.0  10034.00   17885.0   27871.0
# 5    4223.0   54678.704002  39524.854093    0.0  27301.00   44236.0   71510.5
# 6    4223.0   67456.139474  44365.501450    5.0  36566.00   56096.0   87153.0
# 7    4266.0   76848.171120  48096.419369   20.0  43349.25   65800.0   97997.5
# 8    4214.0   89196.256289  55489.671738    5.0  52464.00   77000.0  110000.0
# 9    4180.0   98605.002392  55786.326270    1.0  62000.00   89225.0  122692.5
# 10   4266.0  110138.566807  56132.581230  168.0  72113.00   99000.0  137495.5
# 11   4221.0  122794.362000  58950.245865    1.0  82000.00  112000.0  154000.0
# ...

# %% [markdown]
# # how many cars realted by gear?

# %%
cars.groupby('gear').describe()
# Out:
#                 mileage                                                       \
#                   count          mean           std    min      25%      50%
# gear
# Automatic       15787.0  63406.338760  65483.785526    0.0  12766.0  43990.0
# Manual          30562.0  75169.042111  60715.679323    0.0  26553.5  67632.5
# Semi-automatic     56.0  83868.732143  59026.868909  250.0  42925.5  68280.0
#
#                                        price                ...     hp         \
#                      75%        max    count          mean  ...    75%    max
# gear                                                        ...
# Automatic        94313.5   527205.0  15787.0  28216.003737  ...  211.5  850.0
# Manual          109522.0  1111111.0  30562.0  10572.654244  ...  125.0  649.0
# Semi-automatic  112905.5   307000.0     56.0   8424.982143  ...   95.0  408.0
#
#                     age
#                   count      mean       std  min  25%   50%   75%   max
# gear
# ...

# %% [markdown]
# # what is the lowest price for all

# %%
cars.groupby('price').min()
# Out:
#          mileage           make      model      fuel       gear offerType  \
# price
# 1100      204000        Citroen         C1  Gasoline     Manual      Used
# 1190      100611           Lada     Priora  Gasoline     Manual      Used
# 1250      153000         Toyota       Aygo  Gasoline     Manual      Used
# 1299      222000        Peugeot        206    Diesel     Manual      Used
# 1300      133000           Opel      Corsa  Gasoline     Manual      Used
# ...          ...            ...        ...       ...        ...       ...
# 449900      3600    Lamborghini  Aventador  Gasoline  Automatic      Used
# 465000       350  Mercedes-Benz        SLS  Gasoline  Automatic      Used
# 499800      3400        Maybach    Pullman  Gasoline  Automatic      Used
# 717078        90        Maybach    Pullman  Gasoline  Automatic      Used
# 1199900      431        Ferrari        F12  Gasoline  Automatic      Used
#
#             hp  age
# price
# 1100      68.0   12
# 1190      98.0   12
# ...

# %% [markdown]
# # how many cars for each Company?

# %%
cars.groupby('make').describe()
# Out:
#            mileage                                                             \
#              count           mean           std       min       25%       50%
# make
# 9ff            1.0   39500.000000           NaN   39500.0   39500.0   39500.0
# Abarth        43.0   25528.418605  41562.012025       0.0      10.0      20.0
# Aixam          3.0     403.333333    689.933572       5.0       5.0       5.0
# Alfa         132.0   70702.265152  65501.591562       2.0    8676.0   63250.0
# Alpina        10.0   45362.000000  29128.172296    1000.0   29436.5   47196.5
# ...            ...            ...           ...       ...       ...       ...
# Trucks-Lkw     1.0  312000.000000           NaN  312000.0  312000.0  312000.0
# Volkswagen  6931.0   80802.309335  66097.563988       1.0   25285.5   69500.0
# Volvo        804.0   67107.405473  59861.455586       5.0   22803.0   47567.5
# Zhidou         1.0    3000.000000           NaN    3000.0    3000.0    3000.0
# ...

# %% [markdown]
# # How many cars for each model?

# %%
cars.groupby('model').describe()
# Out:
#       mileage                                                            \
#         count           mean           std      min       25%       50%
# model
# 107      42.0   85833.404762  43180.768863   9981.0  56843.25   82420.0
# 108     216.0   22142.847222  22169.959318      3.0   2922.00   17245.0
# 114      41.0  118466.073171  44007.146878  45200.0  91000.00  107935.0
# 116     225.0  111181.737778  51947.358436   1590.0  74970.00  104700.0
# 118     174.0  103513.505747  60613.130710     41.0  52375.00   99675.0
# ...       ...            ...           ...      ...       ...       ...
# iQ       12.0   92509.333333  43865.005353  26102.0  63266.00   79515.0
# iX20    101.0   75239.772277  53081.188070      0.0  47500.00   69815.0
# iX3       1.0      45.000000           NaN     45.0     45.00      45.0
# iX35     96.0   97433.614583  52044.646983      5.0  64515.75   90840.0
# up!     945.0   55040.931217  35611.859301      3.0  30123.00   48735.0
#
# ...

# %% [markdown]
# 2) how many cars that relased in 2022

# %%
cars[cars['age']>1]['age']
# Out:
# 0        12
# 1        12
# 2        12
# 3        12
# 4        12
#          ..
# 46400     2
# 46401     2
# 46402     2
# 46403     2
# 46404     2
# Name: age, Length: 46405, dtype: int64

# %%
from sklearn.preprocessing import MinMaxScaler
from sklearn.pipeline import Pipeline
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import OneHotEncoder
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, mean_absolute_error

# %%
# These are the numerical attributes of our cars dataset
# Note that the "price" variable is the target variable and is not part of this list
num_attribs = ['mileage','hp','age']

# This is a pipeline that we will apply to the numerical attributes
# The purpose of this pipeline is to rescale the numerical attributes
# to be between 0 and 1
num_pipeline = Pipeline([
    ('min_max_scaler', MinMaxScaler()),
])

# These are the categorical attributes of our dataset
cat_attribs = ['make','model','fuel','gear']

# Define a ColumnTransformer object which will transform the columns of our dataset 
# by applying the numerical pipeline (min-max scaler) to each numerical attribute
# and applying the one-hot encoder to each categorical attribute
full_pipeline_cars = ColumnTransformer([
    ('num', num_pipeline, num_attribs),
    ('cat', OneHotEncoder(), cat_attribs),
])

# Fit the full pipeline to the cars dataset
cars_prepared = full_pipeline_cars.fit_transform(cars)

# The target column is the 'price' 
labels_cars = cars['price']

# Define a linear regressor
lin_reg_cars = LinearRegression()

# Fit the linear regressor to the prepared cars dataset
lin_reg_cars.fit(cars_prepared, labels_cars)

# Use the resulting linear regression parameters to predict the price of each datapoint (car) in the dataset
price_predictions_cars = lin_reg_cars.predict(cars_prepared)

# Find the mean square error of our predictions over the whole dataset
lin_mse_cars = mean_squared_error(labels_cars, price_predictions_cars)

# Find the root mean square error
lin_rmse_cars = np.sqrt(lin_mse_cars)
print("RMSE of the linear regression price predictions for the cars data set: %.0f" % lin_rmse_cars)

# Find the mean absolute error
lin_mae_cars = mean_absolute_error(labels_cars, price_predictions_cars)
print('MAE of the linear regression price predictions for the cars data set: %.0f' % lin_mae_cars)

# Find the ratio of the RMSE to the mean price of cars in the dataset
print('Ratio of the RMSE to the mean price in the cars dataset: ' , lin_rmse_cars/(cars.price.mean()))

# Find the ratio of the MAE to the mean price of cars in the dataset
print('Ratio of the MAE to the mean price in the cars dataset: ' , lin_mae_cars/(cars.price.mean()))

# Compute the coefficient of determination
print('Coefficient of determination (R^2): ', lin_reg_cars.score(cars_prepared, cars['price']))
# Out:
# RMSE of the linear regression price predictions for the cars data set: 5242
# MAE of the linear regression price predictions for the cars data set: 2756
# Ratio of the RMSE to the mean price in the cars dataset:  0.31633976168536676
# Ratio of the MAE to the mean price in the cars dataset:  0.16630198179198918
# Coefficient of determination (R^2):  0.9262505953593902
